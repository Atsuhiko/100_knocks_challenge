# %% [markdown]
# # Week06. Seabornによる描画（２）

# %% [markdown]
# 参考サイト：http://seaborn.pydata.org/examples/index.html

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# cwdのパスは環境によって書き換える。
# %cd /content/drive/MyDrive/100本ノックチャレンジ/06_Visualization_100_knocks/02_Answers
# %ls -lha
# Out:
# /content/drive/MyDrive/100本ノックチャレンジ/06_Visualization_100_knocks/02_Answers
# total 2.5M
# -rw------- 1 root root  18K Sep 11 02:39 acc_graph.png
# drwx------ 2 root root 4.0K Sep  7 04:46 data/
# -rw------- 1 root root  30K Oct 15 09:23 heatmap.png
# -rw------- 1 root root  18K Sep 11 02:39 loss_graph.png
# -rw------- 1 root root  143 Sep 11 03:08 Pythonによるデータ可視化１００本ノック計画.gdoc
# -rw------- 1 root root 423K Sep 10 03:04 Week01_answer_colab.ipynb
# -rw------- 1 root root 316K Sep 10 03:24 Week02_answer_colab.ipynb
# -rw------- 1 root root 420K Sep 10 06:21 Week03_answer_colab.ipynb
# -rw------- 1 root root 608K Oct  1 10:14 Week04_answer_colab.ipynb
# -rw------- 1 root root 570K Oct 15 09:31 Week05_answer_colab.ipynb
# -rw------- 1 root root  76K Oct 21 09:19 Week06_answer_colab.ipynb

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Titanic dataset

# %%
df = pd.read_csv("./data/titanic_train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Q26. Seaborn を用いて以下の様に、男女 (Sex) 、客室 (Pclass)、寄港地 (Embarked)の数の棒グラフを描画せよ。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.countplot("Sex", data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot("Pclass", data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot("Embarked", data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Q27. Seaborn を用いて以下の様に、男女と客室 (Pclass) をクロスしてそれぞれの数の棒グラフを描画せよ。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 層別化 乗客の性別と客室のランク(1:一番良い、2:真ん中、3:一番よくない)
sns.countplot("Sex", data=df, hue="Pclass")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot("Pclass", data=df, hue="Sex")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Q28. Seaborn を用いて以下の様に、性別、船室と生存者数をクロスした棒グラフを描画せよ。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.countplot("Survived", data=df, hue="Sex")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot("Survived", data=df, hue="Pclass")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Q29. Seaborn を用いて以下の様に、年齢と生存率のグラフを描画せよ。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# peaks for survived/not survived passengers by their age
facet = sns.FacetGrid(df, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, df['Age'].max()))
facet.add_legend()

# %%
# Explore Age distibution 
g = sns.kdeplot(df["Age"][(df["Survived"] == 0) & (df["Age"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["Age"][(df["Survived"] == 1) & (df["Age"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Age")
g.set_ylabel("Frequency")
g = g.legend(["Not Survived","Survived"])

# %% [markdown]
# ## 30. Seaborn を持ちて以下の様に、Age別の生存者の箱ひげ図、バイオリンプロットを描画せよ。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 箱ひげ図、バイオリンプロット
g = sns.factorplot(x="Survived", y = "Age",data = df, kind="box")
g = sns.factorplot(x="Survived", y = "Age",data = df, kind="violin")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# 箱ひげ図
g = sns.factorplot(x="Survived", y = "Age",data = df, kind="box")
# Add jitter with the swarmplot function
g = sns.swarmplot(x="Survived", y = "Age",data = df, color="grey")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# バイオリンプロット
g = sns.factorplot(x="Survived", y = "Age",data = df, kind="violin")
# Add jitter with the swarmplot function
g = sns.swarmplot(x="Survived", y = "Age",data = df, color="grey")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
