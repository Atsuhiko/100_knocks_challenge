# %% [markdown]
# # 初学者向けPandas100本ノックver1.0.3

# %%
# ライブラリーの読み込み
import pandas as pd
import glob

# DataFrameの準備
df = pd.read_csv('./data/titanic3.csv')
df2 = pd.read_csv('./data/data1.csv')
df3 = pd.read_csv('./data/data1_2.csv')
df4 = pd.read_csv('./data/data1_3.csv')
df5 = pd.read_csv('./data/data2.csv',encoding='cp932')

# %% [markdown]
# # データ抽出 (14 - 32)

# %%
# 【31】
# dfの各列の要素数の確認
df.nunique()
# Out:
# pclass          3
# survived        2
# name         1307
# sex             2
# age            98
# sibsp           7
# parch           8
# ticket        929
# fare          281
# cabin         186
# embarked        3
# boat           27
# body          121
# home.dest     369
# dtype: int64

# %%
# 【32】
# dfのembarked列の要素と出現回数の確認

df['embarked'].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %% [markdown]
# # データ加工 (33 - 58)

# %%
# 【33】
# dfのindex名が「3」のage列を
# 30から40に変更し、先頭の5行を表示

df.loc[3,"age"] = 40
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  40.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# 【34】
# dfのsex列にてmale→0、femlae→1に
# 変更し、先頭の5行を表示

df['sex'] = df['sex'].replace({'male': 0, 'female': 1})
df.head()
# Out:
#    pclass  survived                                             name  sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton    1
# 1       1         1                   Allison, Master. Hudson Trevor    0
# 2       1         0                     Allison, Miss. Helen Loraine    1
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  40.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# 【35】
# dfのfare列に100を足して、
# 先頭の5行を表示

df['fare'] = df['fare'] + 100
df.head()
# Out:
#    pclass  survived                                             name  sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton    1
# 1       1         1                   Allison, Master. Hudson Trevor    0
# 2       1         0                     Allison, Miss. Helen Loraine    1
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  311.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  251.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  251.5500  C22 C26        S  NaN    NaN
# 3  40.00      1      2  113781  251.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  251.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# 【36】
# dfのfare列を2を掛けて、
# 先頭の5行を表示

df['fare'] = df['fare'] * 2
df.head()
# Out:
#    pclass  survived                                             name  sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton    1
# 1       1         1                   Allison, Master. Hudson Trevor    0
# 2       1         0                     Allison, Miss. Helen Loraine    1
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
#
#      age  sibsp  parch  ticket     fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  622.675       B5        S    2    NaN
# 1   0.92      1      2  113781  503.100  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  503.100  C22 C26        S  NaN    NaN
# 3  40.00      1      2  113781  503.100  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  503.100  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# 【37】
# dfのfare列を小数点以下で丸める

df['fare'] = df['fare'].round()
df.head()
# Out:
#    pclass  survived                                             name  sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton    1
# 1       1         1                   Allison, Master. Hudson Trevor    0
# 2       1         0                     Allison, Miss. Helen Loraine    1
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
#
#      age  sibsp  parch  ticket   fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  623.0       B5        S    2    NaN
# 1   0.92      1      2  113781  503.0  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  503.0  C22 C26        S  NaN    NaN
# 3  40.00      1      2  113781  503.0  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  503.0  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# 【38】
# dfに列名「test」で値がすべて1の
# カラムを追加し、先頭の5行を表示

df['test'] = 1
df.head()
# Out:
#    pclass  survived                                             name  sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton    1
# 1       1         1                   Allison, Master. Hudson Trevor    0
# 2       1         0                     Allison, Miss. Helen Loraine    1
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
#
#      age  sibsp  parch  ticket   fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  623.0       B5        S    2    NaN
# 1   0.92      1      2  113781  503.0  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  503.0  C22 C26        S  NaN    NaN
# 3  40.00      1      2  113781  503.0  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  503.0  C22 C26        S  NaN    NaN
#
#                          home.dest  test
# 0                     St Louis, MO     1
# 1  Montreal, PQ / Chesterville, ON     1
# 2  Montreal, PQ / Chesterville, ON     1
# 3  Montreal, PQ / Chesterville, ON     1
# 4  Montreal, PQ / Chesterville, ON     1

# %%
# 【39】
# dfにcabinとembarkedの列を「_」で
# 結合した列を追加(列名は「test」)し、
# 先頭の5行を表示

# %%
# 【40】
# dfにageとembarkedの列を「_」で
# 結合した列を追加(列名は「test」)し、
# 先頭の5行を表示
