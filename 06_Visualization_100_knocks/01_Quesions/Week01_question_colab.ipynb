# %% [markdown]
# # Week-1. Pandasのデータフレームからの描画（１）

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# cwdのパスは環境によって書き換える。
# %cd /content/drive/MyDrive/100本ノックチャレンジ/06_Visualization_100_knocks/01_Quesions
# %ls -lha
# Out:
# /content/drive/MyDrive/100本ノックチャレンジ/06_Visualization_100_knocks/01_Quesions
# total 424K
# drwx------ 2 root root 4.0K Sep  7 04:46 data/
# -rw------- 1 root root 155K Sep 10 03:18 Week01_question_colab.ipynb
# -rw------- 1 root root 265K Sep 10 03:11 Week02_question_colab.ipynb

# %% [markdown]
# pandas.Series, pandas.DataFrameのメソッドとしてplot()がある。
# Pythonのグラフ描画ライブラリMatplotlibのラッパーで、簡単にグラフを作成できる。

# %%
import pandas as pd

# %% [markdown]
# ## Q１～Q2：折れ線グラフ
# データセット：Pulsar Stars（簡略版）
# https://www.kaggle.com/datasets/colearninglounge/predicting-pulsar-starintermediate

# %%
# CSVファイルの読み込み
# Pulsar stars のデータセット
df = pd.read_csv("data/pulsar_stars_s.csv") # df = data frame の略
df.head()
# Out:
#       Mean_IP      SD_IP  Mean_DM-SNR
# 0  140.562500  55.683782     3.199833
# 1  102.507812  58.882430     1.677258
# 2  103.015625  39.341649     3.121237
# 3  136.750000  57.178449     3.642977
# 4   88.726562  40.672225     1.178930

# %% [markdown]
# ## Q1. dfから３本の折れ線グラフを一つの領域に描きなさい

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 回答欄

# %% [markdown]
# ## Q2. dfより各列の折れ線グラフをそれぞれ別のグラフに分けてに描画しなさい。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 回答欄

# %% [markdown]
# ## Q3. dfより３本の折れ線グラフを表示方法を変えて描画しなさい。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 回答欄

# %% [markdown]
# ## Q4～5 棒グラフ
# データセット：Iris（あやめ）の分類

# %%
# Irisのデータセット
df = pd.read_csv("./data/iris.csv")
df.head()
# Out:
#     a1   a2   a3   a4    id        label
# 0  5.1  3.5  1.4  0.2  id_1  Iris-setosa
# 1  4.9  3.0  1.4  0.2  id_2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  id_3  Iris-setosa
# 3  4.6  3.1  1.5  0.2  id_4  Iris-setosa
# 4  5.0  3.6  1.4  0.2  id_5  Iris-setosa

# %% [markdown]
# ## Q4. dfより縦棒グラフと横棒グラフを作成しなさい。

# %% [markdown]
# ＜縦棒グラフ＞
# ![image.png](data:image/png;base64,...)
#
# ＜横棒グラフ＞
# ![image.png](data:image/png;base64,...)

# %%
# 回答欄

# %% [markdown]
# ## Q5. dfより積み上げ式の棒グラフを描きなさい。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 回答欄
