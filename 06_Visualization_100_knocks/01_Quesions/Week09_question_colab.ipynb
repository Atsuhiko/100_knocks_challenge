# %% [markdown]
# # Week09. Plotly によるインタラクティブ・グラフの描画（１）

# %%
# グラフを画像として保存するために必要
# https://pypi.org/project/kaleido/
# !pip install kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 79.9 MB 95 kB/s
# ...

# %%
# libraries
import pandas as pd
import plotly
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "colab"
plotly.__version__
# Out:
# '5.5.0'

# %% [markdown]
# ## Q41. Plotlyを用いて、Irisのデータセットを用いて、インタラクティブな散布図を描画せよ。また、描画したグラフをpngファイルおよびHTNLファイルで保存せよ。（以下同様）
# 参考URL：https://plotly.com/python/line-and-scatter/

# %%
df = px.data.iris()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %% [markdown]
# ![wk9-41.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q42. Plotlyに登録されている人口のデータから日本、中国、ドイツ、ボツワナの人口と人口当たりのGTPの経年変化のインタラクティブなグラブを描画せよ。
# 参考URL：https://plotly.com/python/line-charts/

# %%
df = px.data.gapminder().query("country in ['Japan', 'China', 'Germany', 'Botswana']")
df.head()
# Out:
#       country continent  year  lifeExp     pop    gdpPercap iso_alpha  iso_num
# 156  Botswana    Africa  1952   47.622  442308   851.241141       BWA       72
# 157  Botswana    Africa  1957   49.618  474639   918.232535       BWA       72
# 158  Botswana    Africa  1962   51.520  512764   983.653976       BWA       72
# 159  Botswana    Africa  1967   53.298  553541  1214.709294       BWA       72
# 160  Botswana    Africa  1972   56.024  619351  2263.611114       BWA       72

# %% [markdown]
# ![wk9-42.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q43. Plotlyに登録されている日本の人口のデータから年単位の人口の推移の棒グラフを描画せよ。また、各棒グラフの色は平均寿命で変化させよ。
# 参考URL：https://plotly.com/python/bar-charts/

# %%
df = px.data.gapminder().query("country == 'Japan'")
df.head()
# Out:
#     country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 792   Japan      Asia  1952    63.03   86459025   3216.956347       JPN
# 793   Japan      Asia  1957    65.50   91563009   4317.694365       JPN
# 794   Japan      Asia  1962    68.73   95831757   6576.649461       JPN
# 795   Japan      Asia  1967    71.43  100825279   9847.788607       JPN
# 796   Japan      Asia  1972    73.42  107188273  14778.786360       JPN
#
#      iso_num
# 792      392
# 793      392
# 794      392
# 795      392
# 796      392

# %% [markdown]
# ![wk9-43.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q44. Plotlyに登録されている世界の人口のデータセットから、アジア、欧州、アフリカ、アメリカ、オセアニア各国の２００７年の人口のインタラクティブなバブルプロットをX軸を人口当たりのGDP、Y軸を平均寿命にしてプロットせよ。また、バブルの色は地域別（アジア、欧州、アフリカ、アメリカ、オセアニア）で塗り分けよ。

# %%
df = px.data.gapminder()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %% [markdown]
# ![wk9-44.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q45. Plotlyに登録されている欧州各国の２００７年の人口のインタラクティブなPie Chartを作成せよ。
# 参考URL：https://plotly.com/python/pie-charts/

# %%
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.head()
# Out:
#                     country continent  year  lifeExp       pop     gdpPercap  \
# 23                  Albania    Europe  2007   76.423   3600523   5937.029526
# 83                  Austria    Europe  2007   79.829   8199783  36126.492700
# 119                 Belgium    Europe  2007   79.441  10392226  33692.605080
# 155  Bosnia and Herzegovina    Europe  2007   74.852   4552198   7446.298803
# 191                Bulgaria    Europe  2007   73.005   7322858  10680.792820
#
#     iso_alpha  iso_num
# 23        ALB        8
# 83        AUT       40
# 119       BEL       56
# 155       BIH       70
# 191       BGR      100

# %% [markdown]
# ![wk9-45.png](data:image/png;base64,...)

# %%
# コード欄
