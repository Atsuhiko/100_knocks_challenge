# %% [markdown]
# # Week07. 散布図アラカルト

# %% [markdown]
# 参考サイト：https://www.python-graph-gallery.com/134-how-to-avoid-overplotting-with-python

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Dataset

# %%
# Dataset:
df=pd.DataFrame({'x': np.random.normal(10, 1.2, 20000), 'y': np.random.normal(10, 1.2, 20000), 'group': np.repeat('A',20000) })
tmp1=pd.DataFrame({'x': np.random.normal(14.5, 1.2, 20000), 'y': np.random.normal(14.5, 1.2, 20000), 'group': np.repeat('B',20000) })
tmp2=pd.DataFrame({'x': np.random.normal(9.5, 1.5, 20000), 'y': np.random.normal(15.5, 1.5, 20000), 'group': np.repeat('C',20000) })
df=df.append(tmp1).append(tmp2)
df.head()
# Out:
#            x          y group
# 0   8.798123   9.592601     A
# 1  11.299585  11.629030     A
# 2   9.358990  10.891395     A
# 3   7.060005  11.228433     A
# 4   9.163655   9.361307     A

# %%
df.tail()
# Out:
#                x          y group
# 19995  12.071155  15.648029     C
# 19996   7.188266  13.677508     C
# 19997  10.158066  14.588085     C
# 19998   8.975144  12.189565     C
# 19999  10.901829  18.455892     C

# %%
# plot
plt.plot( 'x', 'y', "", data=df, linestyle='', marker='o')
plt.xlabel('Value of X')
plt.ylabel('Value of Y')
plt.title('Overplotting looks like that:', loc='left')
plt.show()

# %% [markdown]
# ## Q31. 上記のデータセットを用いて、以下の様にトッドサイズを 0.3 にして散布図を描画せよ。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q32. 上記のデータセットを用いて、以下の様にトッドサイズ（markerezise) を .3、透明度（alpha) を 0.0.5 にして散布図を描画せよ。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q33. 上記のデータセットを用いて、以下の様にグループAだけを青色にフィルタリングしてプロットせよ。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q34. 上記のデータセットを用いて、以下の様にグループ毎に色を変えてプロットせよ。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q35. 上記のデータセットを用いて、以下の様にグループ毎に別々に色を変えてプロットせよ。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# コード欄
