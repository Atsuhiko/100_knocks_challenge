# %% [markdown]
# # Week-3. Matplotlibによる描画（１）

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# cwdのパスは環境によって書き換える。
# %cd /content/drive/MyDrive/100本ノックチャレンジ/06_Visualization_100_knocks/01_Quesions
# %ls -lha
# Out:
# /content/drive/MyDrive/100本ノックチャレンジ/06_Visualization_100_knocks/01_Quesions
# total 497K
# drwx------ 2 root root 4.0K Sep  7 04:46 data/
# -rw------- 1 root root 154K Sep 10 03:34 Week01_question_colab.ipynb
# -rw------- 1 root root 138K Sep 10 03:23 Week02_question_colab.ipynb
# -rw------- 1 root root 202K Sep 10 06:13 Week03_question_colab.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# jupyter内に描画

# %%
# Irisのデータセット
# CSVファイルの読み込み
df = pd.read_csv("./data/iris.csv") # df = dataframe の略
df.head()
# Out:
#     a1   a2   a3   a4    id        label
# 0  5.1  3.5  1.4  0.2  id_1  Iris-setosa
# 1  4.9  3.0  1.4  0.2  id_2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  id_3  Iris-setosa
# 3  4.6  3.1  1.5  0.2  id_4  Iris-setosa
# 4  5.0  3.6  1.4  0.2  id_5  Iris-setosa

# %% [markdown]
# ## Q11. 以下の様なヒストグラムを描きなさい。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q12. 以下の様な散布図を描きなさい。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q13. 以下の様にあやめの種類別に色分けして散布図を描きなさい。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# グラフ描画に必要なリストの定義
feature_names = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
label_list = list(df.label.unique())
print(label_list)
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
# コード欄

# %% [markdown]
# ## Q14. 以下の様にあやめの種類別に色分けして三次元の散布図を描きなさい。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# コード欄

# %% [markdown]
# ## Q15. 以下の様にa1～a4のボックスプロットを描きなさい

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# コード欄
