# %% [markdown]
# # データサイエンス100本ノック（構造化データ加工編） - Python

# %% [markdown]
# ## はじめに
# - 初めに以下のセルを実行してください
# - 必要なライブラリのインポートとデータベース（PostgreSQL）からのデータ読み込みを行います
# - pandas等、利用が想定されるライブラリは以下セルでインポートしています
# - その他利用したいライブラリがあれば適宜インストールしてください（"!pip install ライブラリ名"でインストールも可能）
# - 処理は複数回に分けても構いません
# - 名前、住所等はダミーデータであり、実在するものではありません

# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime, date
from dateutil.relativedelta import relativedelta
import math
import psycopg2
from sqlalchemy import create_engine
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler # conda install -c conda-forge imbalanced-learn

df_customer = pd.read_csv("./data/customer.csv")
df_category = pd.read_csv("./data/category.csv")
df_product = pd.read_csv("./data/product.csv")
df_receipt = pd.read_csv("./data/receipt.csv")
df_store = pd.read_csv("./data/store.csv")
df_geocode = pd.read_csv("./data/geocode.csv")
# Out:
# C:\Users\iiats\Anaconda3\envs\Python36-gpu\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # 演習問題

# %% [markdown]
# ---
# > P-026: レシート明細データフレーム（df_receipt）に対し、顧客ID（customer_id）ごとに最も新しい売上日（sales_ymd）と古い売上日を求め、両者が異なるデータを10件表示せよ。

# %%
df_receipt.head()
# Out:
#    sales_ymd  sales_epoch store_cd  receipt_no  receipt_sub_no  \
# 0   20181103   1257206400   S14006         112               1
# 1   20181118   1258502400   S13008        1132               2
# 2   20170712   1215820800   S14028        1102               1
# 3   20190205   1265328000   S14042        1132               1
# 4   20180821   1250812800   S14025        1102               2
#
#       customer_id  product_cd  quantity  amount
# 0  CS006214000001  P070305012         1     158
# 1  CS008415000097  P070701017         1      81
# 2  CS028414000014  P060101005         1     170
# 3  ZZ000000000000  P050301001         1      25
# 4  CS025415000050  P060102007         1      90

# %%
df_receipt2 = df_receipt.groupby('customer_id').agg({'sales_ymd':['max','min']})
df_receipt2.head()
# Out:
#                sales_ymd
#                      max       min
# customer_id
# CS001113000004  20190308  20190308
# CS001114000005  20190731  20180503
# CS001115000010  20190405  20171228
# CS001205000004  20190625  20170914
# CS001205000006  20190224  20180207

# %%
df_receipt3 = df_receipt2.query('max != min')
df_receipt3.head()
# エラーがでました。groupby した後にカラム名を変更しないといけません。
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# ~\Anaconda3\envs\Python36-gpu\lib\collections\__init__.py in __getitem__(self, key)
#     882                 pass
# --> 883         return self.__missing__(key)            # support subclasses that define __missing__
#     884
#
# ~\Anaconda3\envs\Python36-gpu\lib\collections\__init__.py in __missing__(self, key)
#     874     def __missing__(self, key):
# --> 875         raise KeyError(key)
#     876
#
# KeyError: 'max'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     197                 # e.g., df[df > 0]
# --> 198                 return self.temps[key]
#     199             except KeyError:
#
# KeyError: 'max'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-20-7d45a43a65df> in <module>
# ----> 1 df_receipt3 = df_receipt2.query('max != min')
#       2 df_receipt3.head()
#       3 # エラーがでました。groupby した後にカラム名を変更しないといけません。
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     330         )
#     331
# --> 332         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     333
#     334         # construct the engine and evaluate the parsed expression
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in __init__(self, expr, engine, parser, env, level)
#     762         self.parser = parser
#     763         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 764         self.terms = self.parse()
#     765
#     766     @property
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in parse(self)
#     779     def parse(self):
#     780         """Parse an expression"""
# --> 781         return self._visitor.visit(self.expr)
#     782
#     783     @property
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in visit_Module(self, node, **kwargs)
#     379             raise SyntaxError("only a single expression is allowed")
#     380         expr = node.body[0]
# --> 381         return self.visit(expr, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in visit_Expr(self, node, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
# --> 384         return self.visit(node.value, **kwargs)
#     385
#     386     def _rewrite_membership_op(self, node, left, right):
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in visit_Compare(self, node, **kwargs)
#     674             op = self.translate_In(ops[0])
#     675             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 676             return self.visit(binop)
#     677
#     678         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in visit_BinOp(self, node, **kwargs)
#     495
#     496     def visit_BinOp(self, node, **kwargs):
# --> 497         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     498         left, right = self._maybe_downcast_constants(left, right)
#     499         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     414     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     415         if left is None:
# --> 416             left = self.visit(node.left, side="left")
#     417         if right is None:
#     418             right = self.visit(node.right, side="right")
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\expr.py in visit_Name(self, node, **kwargs)
#     508
#     509     def visit_Name(self, node, **kwargs):
# --> 510         return self.term_type(node.id, self.env, **kwargs)
#     511
#     512     def visit_NameConstant(self, node, **kwargs):
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\ops.py in __init__(self, name, env, side, encoding)
#      80         tname = str(name)
#      81         self.is_local = tname.startswith(_LOCAL_TAG) or tname in _DEFAULT_GLOBALS
# ---> 82         self._value = self._resolve_name()
#      83         self.encoding = encoding
#      84
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\ops.py in _resolve_name(self)
#      97
#      98     def _resolve_name(self):
# ---> 99         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     100         self.update(res)
#     101
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     201                 from pandas.core.computation.ops import UndefinedVariableError
#     202
# --> 203                 raise UndefinedVariableError(key, is_local)
#     204
#     205     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'max' is not defined

# %%
# 参照：https://qiita.com/fuppi/items/e6657860f22beae84a03

df_receipt3 = df_receipt2.agg({"sales_ymd": {"sales_ymd_max": "max","sales_ymd_min": "min"}})
df_receipt3.head()
# まだまだエラーが続くのでギブアップして解答例を見ます。
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-21-70969fd5ba2d> in <module>
#       1 # 参照：https://qiita.com/fuppi/items/e6657860f22beae84a03
#       2
# ----> 3 df_receipt3 = df_receipt2.agg({"sales_ymd": {"sales_ymd_max": "max","sales_ymd_min": "min"}})
#       4 df_receipt3.head()
#       5 # まだまだエラーが続くのでギブアップして解答例を見ます。
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\frame.py in aggregate(self, func, axis, *args, **kwargs)
#    6704         result = None
#    6705         try:
# -> 6706             result, how = self._aggregate(func, axis=axis, *args, **kwargs)
#    6707         except TypeError:
#    6708             pass
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\frame.py in _aggregate(self, arg, axis, *args, **kwargs)
#    6718             result = result.T if result is not None else result
#    6719             return result, how
# -> 6720         return super()._aggregate(arg, *args, **kwargs)
#    6721
#    6722     agg = aggregate
#
# ~\Anaconda3\envs\Python36-gpu\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     340                     # {'ra' : { 'A' : 'mean' }}
#     341                     if isinstance(v, dict):
# --> 342                         raise SpecificationError("nested renamer is not supported")
#     343                     elif isinstance(obj, ABCSeries):
#     344                         raise SpecificationError("nested renamer is not supported")
#
# SpecificationError: nested renamer is not supported

# %%
df_receipt2.columns = ["_".join(pair) for pair in df_receipt2.columns]
df_receipt2.head()
# Out:
#                 sales_ymd_max  sales_ymd_min
# customer_id
# CS001113000004       20190308       20190308
# CS001114000005       20190731       20180503
# CS001115000010       20190405       20171228
# CS001205000004       20190625       20170914
# CS001205000006       20190224       20180207

# %%
# 解答例を見ちゃんいました
df_receipt3 = df_receipt2.query('sales_ymd_max != sales_ymd_min')
df_receipt3.head(10)

# カラム名の行が揃ってないけどなんとかできました。
# Out:
#                 sales_ymd_max  sales_ymd_min
# customer_id
# CS001114000005       20190731       20180503
# CS001115000010       20190405       20171228
# CS001205000004       20190625       20170914
# CS001205000006       20190224       20180207
# CS001214000009       20190902       20170306
# CS001214000017       20191006       20180828
# CS001214000048       20190929       20171109
# CS001214000052       20190617       20180208
# CS001215000005       20181021       20170206
# CS001215000040       20171022       20170214

# %%
# 27問目をやった段階でreset_index()メソッドを使って、26問目もやり直し。
df_receipt2 = df_receipt.groupby('customer_id').agg({'sales_ymd':['max','min']}).reset_index()
df_receipt2.columns = ["_".join(pair) for pair in df_receipt2.columns]
df_receipt3 = df_receipt2.query('sales_ymd_max != sales_ymd_min')
df_receipt3.head(10)
# Out:
#       customer_id_  sales_ymd_max  sales_ymd_min
# 1   CS001114000005       20190731       20180503
# 2   CS001115000010       20190405       20171228
# 3   CS001205000004       20190625       20170914
# 4   CS001205000006       20190224       20180207
# 13  CS001214000009       20190902       20170306
# 14  CS001214000017       20191006       20180828
# 16  CS001214000048       20190929       20171109
# 17  CS001214000052       20190617       20180208
# 20  CS001215000005       20181021       20170206
# 21  CS001215000040       20171022       20170214

# %%
# できました！

# %% [markdown]
# ---
# > P-027: レシート明細データフレーム（df_receipt）に対し、店舗コード（store_cd）ごとに売上金額（amount）の平均を計算し、降順でTOP5を表示せよ。

# %%
df_receipt2 = df_receipt.groupby('store_cd').agg({'amount':'mean'})
df_receipt2.head()
# Out:
#               amount
# store_cd
# S12007    307.688343
# S12013    330.194130
# S12014    310.830261
# S12029    315.623908
# S12030    288.533727

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html
df_receipt3 = df_receipt2.sort_values('amount', ascending=False)
df_receipt3.head()
# Out:
#               amount
# store_cd
# S13052    402.867470
# S13015    351.111960
# S13003    350.915519
# S14010    348.791262
# S13001    348.470386

# %%
# やっぱりカラム名が揃いません。解答例にある reset_index() メソッドを使ってやり直します。
df_receipt2 = df_receipt.groupby('store_cd').agg({'amount':'mean'}).reset_index()
df_receipt3 = df_receipt2.sort_values('amount', ascending=False)
df_receipt3.head()
# Out:
#    store_cd      amount
# 28   S13052  402.867470
# 12   S13015  351.111960
# 7    S13003  350.915519
# 30   S14010  348.791262
# 5    S13001  348.470386

# %%
# きちんとできました。reset_index() メソッド覚えました。

# %% [markdown]
# ---
# > P-028: レシート明細データフレーム（df_receipt）に対し、店舗コード（store_cd）ごとに売上金額（amount）の中央値を計算し、降順でTOP5を表示せよ。

# %%
# もうコツがつかめたので、簡潔なコードで
df_receipt2 = df_receipt.groupby('store_cd').agg({'amount':'median'}).reset_index().sort_values('amount', ascending=False)
df_receipt2.head()
# Out:
#    store_cd  amount
# 28   S13052     190
# 30   S14010     188
# 51   S14050     185
# 44   S14040     180
# 7    S13003     180

# %% [markdown]
# ---
# > P-029: レシート明細データフレーム（df_receipt）に対し、店舗コード（store_cd）ごとに商品コード（product_cd）の最頻値を求めよ。

# %%
# df_receipt の構造を確認
df_receipt.head()
# Out:
#    sales_ymd  sales_epoch store_cd  receipt_no  receipt_sub_no  \
# 0   20181103   1257206400   S14006         112               1
# 1   20181118   1258502400   S13008        1132               2
# 2   20170712   1215820800   S14028        1102               1
# 3   20190205   1265328000   S14042        1132               1
# 4   20180821   1250812800   S14025        1102               2
#
#       customer_id  product_cd  quantity  amount
# 0  CS006214000001  P070305012         1     158
# 1  CS008415000097  P070701017         1      81
# 2  CS028414000014  P060101005         1     170
# 3  ZZ000000000000  P050301001         1      25
# 4  CS025415000050  P060102007         1      90

# %%
# 参考：lambdaについて https://yuru-d.com/series-apply-lambda/
# 参考：mode()について https://note.nkmk.me/python-statistics-mean-median-mode-var-stdev/
df_receipt2 = df_receipt.groupby('store_cd')
df_receipt3 = df_receipt2.product_cd.apply(lambda x: x.mode())
df_receipt3
# Out:
# store_cd
# S12007    0    P060303001
# S12013    0    P060303001
# S12014    0    P060303001
# S12029    0    P060303001
# S12030    0    P060303001
# S13001    0    P060303001
# S13002    0    P060303001
# S13003    0    P071401001
# S13004    0    P060303001
# S13005    0    P040503001
# S13008    0    P060303001
# S13009    0    P060303001
# S13015    0    P071401001
# S13016    0    P071102001
# S13017    0    P060101002
# S13018    0    P071401001
# S13019    0    P071401001
# S13020    0    P071401001
# S13031    0    P060303001
# S13032    0    P060303001
# S13035    0    P040503001
# S13037    0    P060303001
# S13038    0    P060303001
# S13039    0    P071401001
# S13041    0    P071401001
# S13043    0    P060303001
# S13044    0    P060303001
# S13051    0    P050102001
#           1    P071003001
#           2    P080804001
# S13052    0    P050101001
# S14006    0    P060303001
# S14010    0    P060303001
# S14011    0    P060101001
# S14012    0    P060303001
# S14021    0    P060101001
# S14022    0    P060303001
# S14023    0    P071401001
# S14024    0    P060303001
# S14025    0    P060303001
# S14026    0    P071401001
# S14027    0    P060303001
# S14028    0    P060303001
# S14033    0    P071401001
# S14034    0    P060303001
# S14036    0    P040503001
#           1    P060101001
# S14040    0    P060303001
# S14042    0    P050101001
# S14045    0    P060303001
# S14046    0    P060303001
# S14047    0    P060303001
# S14048    0    P050101001
# S14049    0    P060303001
# S14050    0    P060303001
# Name: product_cd, dtype: object

# %%
# reset_index()を入れないとDataFrame型にならない。
df_receipt2 = df_receipt.groupby('store_cd')
df_receipt3 = df_receipt2.product_cd.apply(lambda x: x.mode()).reset_index()
df_receipt3
# Out:
#    store_cd  level_1  product_cd
# 0    S12007        0  P060303001
# 1    S12013        0  P060303001
# 2    S12014        0  P060303001
# 3    S12029        0  P060303001
# 4    S12030        0  P060303001
# 5    S13001        0  P060303001
# 6    S13002        0  P060303001
# 7    S13003        0  P071401001
# 8    S13004        0  P060303001
# 9    S13005        0  P040503001
# 10   S13008        0  P060303001
# 11   S13009        0  P060303001
# 12   S13015        0  P071401001
# 13   S13016        0  P071102001
# 14   S13017        0  P060101002
# 15   S13018        0  P071401001
# 16   S13019        0  P071401001
# 17   S13020        0  P071401001
# 18   S13031        0  P060303001
# 19   S13032        0  P060303001
# 20   S13035        0  P040503001
# 21   S13037        0  P060303001
# 22   S13038        0  P060303001
# 23   S13039        0  P071401001
# 24   S13041        0  P071401001
# 25   S13043        0  P060303001
# 26   S13044        0  P060303001
# 27   S13051        0  P050102001
# 28   S13051        1  P071003001
# 29   S13051        2  P080804001
# 30   S13052        0  P050101001
# 31   S14006        0  P060303001
# 32   S14010        0  P060303001
# 33   S14011        0  P060101001
# 34   S14012        0  P060303001
# 35   S14021        0  P060101001
# 36   S14022        0  P060303001
# 37   S14023        0  P071401001
# 38   S14024        0  P060303001
# 39   S14025        0  P060303001
# 40   S14026        0  P071401001
# 41   S14027        0  P060303001
# 42   S14028        0  P060303001
# 43   S14033        0  P071401001
# 44   S14034        0  P060303001
# 45   S14036        0  P040503001
# 46   S14036        1  P060101001
# 47   S14040        0  P060303001
# 48   S14042        0  P050101001
# 49   S14045        0  P060303001
# 50   S14046        0  P060303001
# 51   S14047        0  P060303001
# 52   S14048        0  P050101001
# 53   S14049        0  P060303001
# 54   S14050        0  P060303001

# %% [markdown]
# ---
# > P-030: レシート明細データフレーム（df_receipt）に対し、店舗コード（store_cd）ごとに売上金額（amount）の標本分散を計算し、降順でTOP5を表示せよ。

# %%
# 参考；標準分散を pandas で出す方法　https://it-engineer-lab.com/archives/1065
df_receipt2 = df_receipt.groupby('store_cd').amount.var(ddof=0).reset_index()
df_receipt2.head()
# Out:
#   store_cd         amount
# 0   S12007  199878.572908
# 1   S12013  221059.615563
# 2   S12014  200946.440113
# 3   S12029  194078.594456
# 4   S12030  185542.898104

# %%
df_receipt3 = df_receipt2.sort_values('amount', ascending=False)
df_receipt3.head()
# Out:
#    store_cd         amount
# 28   S13052  440088.701311
# 31   S14011  306314.558164
# 42   S14034  296920.081011
# 5    S13001  295431.993329
# 12   S13015  295294.361116
